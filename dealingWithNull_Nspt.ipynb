# %% [markdown]
# <a href="https://colab.research.google.com/github/mazibazi/dataScienceGeo/blob/main/dealingWithNull_Nspt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # import Lib and File

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sb
import plotly.express as px
import plotly.graph_objects as go
from sklearn.metrics import mean_absolute_error

# %%
path = '/content/gdrive/MyDrive/Colab Notebooks/dataAnalySPT/datasetSelectedLine4SoilPro.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    Unnamed: 0      Code  DepthUp  DepthDown     Soil  Density    qu  \
# 0           0  S1_TI-2C      2.0        2.6  Filling      NaN   NaN
# 1           1  S1_TI-2C      9.0        9.6     Clay    1.818   NaN
# 2           2  S1_TI-2C     23.5       24.1     Sand    2.006  2.35
# 3           3  S1_TI-2C     29.5       30.1     Sand    2.050   NaN
# 4           4  S1_TI-2C     40.0       40.6     Marl    2.102   NaN
#
#    Cu_directshear  Phi_directshear  Cu_triaxial  Phi_triaxial    Cu    Phi  \
# 0             NaN              NaN          NaN           NaN   NaN    NaN
# 1            0.49             23.0          NaN           NaN  0.49  23.00
# 2             NaN              NaN         0.20         30.31  0.20  30.31
# 3            0.47             23.5          NaN           NaN  0.47  23.50
# 4             NaN              NaN         0.44         20.10  0.44  20.10
#
#    Nspt             Address  Latitude  Longitude
# 0   NaN  Av. Reina Mercedes  37.36079  -5.988427
# 1  20.0  Av. Reina Mercedes  37.36079  -5.988427
# 2  31.0  Av. Reina Mercedes  37.36079  -5.988427
# 3   NaN  Av. Reina Mercedes  37.36079  -5.988427
# 4   NaN  Av. Reina Mercedes  37.36079  -5.988427

# %% [markdown]
# # Dataset rename

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.columns
# Out:
# Index(['Code', 'DepthUp', 'DepthDown', 'Soil', 'Density', 'qu',
#        'Cu_directshear', 'Phi_directshear', 'Cu_triaxial', 'Phi_triaxial',
#        'Cu', 'Phi', 'Nspt', 'Address', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.shape
# Out:
# (133, 16)

# %%
targetSoil = ["Clay", "Sand"]
gravelSoil = {"Gravel"}
deepSoil = ["Marl"]
fillSoil = ["Filling"]

df1 = df[df["Soil"].isin(targetSoil)]
df2 = df[df["Soil"].isin(gravelSoil)]
df3 = df[df["Soil"].isin(deepSoil)]
df0 = df[df["Soil"].isin(fillSoil)]
print(f"Number of report that are located in \nfilling: {df0.shape[0]}\nClay and Sand: {df1.shape[0]}\nGravel: {df2.shape[0]} \nMarl: {df3.shape[0]}")
# Out:
# Number of report that are located in
# filling: 18
# Clay and Sand: 55
# Gravel: 15
# Marl: 41

# %%
dfFirst = df1.iloc[:,[0,1,2,3,4,-4,-5,-6,-1,-2,-3]]
dfFirst.columns
# Out:
# Index(['Code', 'DepthUp', 'DepthDown', 'Soil', 'Density', 'Nspt', 'Phi', 'Cu',
#        'Longitude', 'Latitude', 'Address'],
#       dtype='object')

# %% [markdown]
# # Dealing with Null data

# %%
dfFirst.isna().sum()
# Out:
# Code          0
# DepthUp       0
# DepthDown     0
# Soil          0
# Density      26
# Nspt         23
# Phi          26
# Cu           26
# Longitude     0
# Latitude      0
# Address       0
# dtype: int64

# %% [markdown]
# We can see 23 Nspt and 26 Cohession are not reported, so we are going to check these data are similar or they may have cover each other.

# %%
(dfFirst.iloc[:,5].isna() & dfFirst.iloc[:,7].isna()).sum()
# Out:
# 8

# %% [markdown]
# So, we have already seen these 8 data in the previouse file. And I have already checked that these SPT reports are complete in other layers. So I am going tp remove this Rows.

# %%
dfFirst[dfFirst["Nspt"].isnull() & dfFirst["Cu"].isnull()]
# Out:
#            Code  DepthUp  DepthDown  Soil  Density  Nspt  Phi  Cu  Longitude  \
# 43     S4_TVI-1      4.0        4.6  Clay    0.850   NaN  NaN NaN  -6.010093
# 66   S1_TVIII-1      8.0        8.6  Sand    1.868   NaN  NaN NaN  -5.997485
# 81   S3_TVIII-1     14.0       14.6  Clay    1.888   NaN  NaN NaN  -5.994372
# 94    S8_TVII-2     16.0       16.6  Sand    2.150   NaN  NaN NaN  -6.009896
# 100     S2_TV-2      4.0        4.6  Clay    1.840   NaN  NaN NaN  -5.994999
# 109     S3_TV-2      7.0        7.6  Sand    2.010   NaN  NaN NaN  -5.996847
# 117   S9_TVII-2     10.0       10.6  Sand      NaN   NaN  NaN NaN  -6.005359
# 121  S10_TVII-2     10.0       10.6  Sand      NaN   NaN  NaN NaN  -6.008791
#
#       Latitude                        Address
# 43   37.398565            C/ Americo Vespucio
# 66   37.369618  C/ Antonio Bienvenida (Feria)
# 81   37.364774              Puerto de Sevilla
# 94   37.381862                   Ronda Triana
# 100  37.409252              Av. Alvaro Alonso
# 109  37.409546           C/ J. Bautista Muñoz
# 117  37.375627                    C/ Santa Fe
# 121  37.380210                Lopez de Gomara

# %%
indexNull = dfFirst[dfFirst["Nspt"].isnull() & dfFirst["Cu"].isnull()].index.values
indexNull
# Out:
# array([ 43,  66,  81,  94, 100, 109, 117, 121])

# %%
dfFirst[dfFirst["Nspt"].isnull() & dfFirst["Cu"].isnull()]["Code"].values
# Out:
# array(['S4_TVI-1', 'S1_TVIII-1', 'S3_TVIII-1', 'S8_TVII-2', 'S2_TV-2',
#        'S3_TV-2', 'S9_TVII-2', 'S10_TVII-2'], dtype=object)

# %%
if dfFirst.drop(indexNull).shape[0] == len(dfFirst)-len(indexNull):
  print(f"It was Right and the lenghth of new data fram is {dfFirst.drop(indexNull).shape[0]}\nAnd {len(indexNull)} are removed which {round(len(indexNull)/len(dfFirst)*100)}% of dataset is removed")
  dfDealP = dfFirst.drop(indexNull)
# Out:
# It was Right and the lenghth of new data fram is 47
# And 8 are removed which 15% of dataset is removed

# %%
dfDealP.head(3)
# Out:
#        Code  DepthUp  DepthDown  Soil  Density  Nspt    Phi    Cu  Longitude  \
# 1  S1_TI-2C      9.0        9.6  Clay    1.818  20.0  23.00  0.49  -5.988427
# 2  S1_TI-2C     23.5       24.1  Sand    2.006  31.0  30.31  0.20  -5.988427
# 3  S1_TI-2C     29.5       30.1  Sand    2.050   NaN  23.50  0.47  -5.988427
#
#    Latitude             Address
# 1  37.36079  Av. Reina Mercedes
# 2  37.36079  Av. Reina Mercedes
# 3  37.36079  Av. Reina Mercedes

# %% [markdown]
# ## Now we are going to find Soil Properties of dataset

# %% [markdown]
# #### Using Formula
# [Ranjan Kumar](https://link.springer.com/article/10.1007/s41403-016-0012-6)<br>
# [Mahmoud](https://www.researchgate.net/profile/Nirmala-Svsg/post/About_shear_strength_test_of_soils_what_would_be_the_most_reliable_test/attachment/59d6370279197b8077994636/AS%3A391268300541953%401470297040155/download/42.pdf)

# %% [markdown]
# ##### Find Cohession

# %% [markdown]
# for range **20-30**:<br>
# $C1 = -2.2049 + 6.484N$<br>
# for range **10-30**:<br>
# $C2 = -16.5+2.15N$ <br>
# General<br>
# $C3 =0.014N-0.18$

# %%
dfDealP.insert(7,"C1", round(-2.2049+ dfDealP["Nspt"]*6.484,3))
# dfDealP.drop("C1", axis = 1, inplace=True)
dfDealP.head(5)
# Out:
#         Code  DepthUp  DepthDown  Soil  Density  Nspt    Phi       C1    Cu  \
# 1   S1_TI-2C      9.0        9.6  Clay    1.818  20.0  23.00  127.475  0.49
# 2   S1_TI-2C     23.5       24.1  Sand    2.006  31.0  30.31  198.799  0.20
# 3   S1_TI-2C     29.5       30.1  Sand    2.050   NaN  23.50      NaN  0.47
# 6  S1_TVII-2      7.2        7.8  Clay    2.156  10.0  23.64   62.635  0.18
# 7  S1_TVII-2      9.7       10.3  Clay    2.063   NaN  23.14      NaN  0.52
#
#    Longitude  Latitude             Address
# 1  -5.988427  37.36079  Av. Reina Mercedes
# 2  -5.988427  37.36079  Av. Reina Mercedes
# 3  -5.988427  37.36079  Av. Reina Mercedes
# 6  -6.010817  37.39085            C/ Odiel
# 7  -6.010817  37.39085            C/ Odiel

# %%
dfDealP.insert(7,"C2", round(-16.5+2.15*dfDealP["Nspt"],3))
# dfDealP.drop("C2", axis = 1, inplace=True)
dfDealP.head(5)
# Out:
#         Code  DepthUp  DepthDown  Soil  Density  Nspt    Phi     C2       C1  \
# 1   S1_TI-2C      9.0        9.6  Clay    1.818  20.0  23.00  26.50  127.475
# 2   S1_TI-2C     23.5       24.1  Sand    2.006  31.0  30.31  50.15  198.799
# 3   S1_TI-2C     29.5       30.1  Sand    2.050   NaN  23.50    NaN      NaN
# 6  S1_TVII-2      7.2        7.8  Clay    2.156  10.0  23.64   5.00   62.635
# 7  S1_TVII-2      9.7       10.3  Clay    2.063   NaN  23.14    NaN      NaN
#
#      Cu  Longitude  Latitude             Address
# 1  0.49  -5.988427  37.36079  Av. Reina Mercedes
# 2  0.20  -5.988427  37.36079  Av. Reina Mercedes
# 3  0.47  -5.988427  37.36079  Av. Reina Mercedes
# 6  0.18  -6.010817  37.39085            C/ Odiel
# 7  0.52  -6.010817  37.39085            C/ Odiel

# %%
dfDealP.insert(7,"C3", round(0.014*dfDealP["Nspt"]-0.18,3))
# dfDealP.drop("C3", axis = 1, inplace=True)
dfDealP.head(5)
# Out:
#         Code  DepthUp  DepthDown  Soil  Density  Nspt    Phi     C3     C2  \
# 1   S1_TI-2C      9.0        9.6  Clay    1.818  20.0  23.00  0.100  26.50
# 2   S1_TI-2C     23.5       24.1  Sand    2.006  31.0  30.31  0.254  50.15
# 3   S1_TI-2C     29.5       30.1  Sand    2.050   NaN  23.50    NaN    NaN
# 6  S1_TVII-2      7.2        7.8  Clay    2.156  10.0  23.64 -0.040   5.00
# 7  S1_TVII-2      9.7       10.3  Clay    2.063   NaN  23.14    NaN    NaN
#
#         C1    Cu  Longitude  Latitude             Address
# 1  127.475  0.49  -5.988427  37.36079  Av. Reina Mercedes
# 2  198.799  0.20  -5.988427  37.36079  Av. Reina Mercedes
# 3      NaN  0.47  -5.988427  37.36079  Av. Reina Mercedes
# 6   62.635  0.18  -6.010817  37.39085            C/ Odiel
# 7      NaN  0.52  -6.010817  37.39085            C/ Odiel

# %%
dfTestMeth = dfDealP.dropna(subset=['Cu', 'C1','C2','C3'])
dfTestMeth.shape
# Out:
# (14, 14)

# %% [markdown]
# ###### Mean Absolute Erro

# %%
MAEC1 = round(mean_absolute_error(dfTestMeth["Cu"]*98.0665,dfTestMeth["C1"]),2)
MAEC2 = round(mean_absolute_error(dfTestMeth["Cu"]*98.0665,dfTestMeth["C2"]),2)
MAEC3 = round(mean_absolute_error(dfTestMeth["Cu"],dfTestMeth["C3"]),2)
print(f"The MAE for C1 is: {(MAEC1)}\nThe MAE fpr C2 is: {MAEC2}\nThe MAE fpr C3 is: {MAEC3}")
#round(mean_absolute_error(dfTestMeth["Cu"],dfTestMeth["C3"]),2)
# Out:
# The MAE for C1 is: 104.56
# The MAE fpr C2 is: 18.67
# The MAE fpr C3 is: 0.23

# %%
dfDealP[dfDealP["C3"] <=0.01]
# Out:
#           Code  DepthUp  DepthDown  Soil  Density  Nspt    Phi     C3    C2  \
# 6    S1_TVII-2      7.2        7.8  Clay    2.156  10.0  23.64 -0.040  5.00
# 102    S2_TV-2     10.0       10.6  Sand      NaN  10.0    NaN -0.040  5.00
# 108    S3_TV-2      4.0        4.6  Sand    1.900  11.0    NaN -0.026  7.15
# 116  S9_TVII-2      4.0        4.6  Sand      NaN   4.0    NaN -0.124 -7.90
#
#          C1    Cu  Longitude   Latitude               Address
# 6    62.635  0.18  -6.010817  37.390850              C/ Odiel
# 102  62.635   NaN  -5.994999  37.409252     Av. Alvaro Alonso
# 108  69.119   NaN  -5.996847  37.409546  C/ J. Bautista Muñoz
# 116  23.731   NaN  -6.005359  37.375627           C/ Santa Fe

# %%
dfDealP[dfDealP["Nspt"] <=10]
# Out:
#           Code  DepthUp  DepthDown  Soil  Density  Nspt    Phi     C3   C2  \
# 6    S1_TVII-2      7.2        7.8  Clay    2.156  10.0  23.64 -0.040  5.0
# 102    S2_TV-2     10.0       10.6  Sand      NaN  10.0    NaN -0.040  5.0
# 116  S9_TVII-2      4.0        4.6  Sand      NaN   4.0    NaN -0.124 -7.9
#
#          C1    Cu  Longitude   Latitude            Address
# 6    62.635  0.18  -6.010817  37.390850           C/ Odiel
# 102  62.635   NaN  -5.994999  37.409252  Av. Alvaro Alonso
# 116  23.731   NaN  -6.005359  37.375627        C/ Santa Fe

# %% [markdown]
# **So We can find out the C2 shows the Cohession way much better that C1 for our study points.**<br>
# But we can see C3 works way much better for Nspt bigger than 10
# **Note:** *So we can use C3 for finidng Sand and Clay properties, we have to use C1 for Rows 6, 102, 108 and 116.*

# %% [markdown]
# ##### Find friction angle

# %% [markdown]
# for range **N<= 4**:<br>
# $\phi1= 7N$<br>
# for range **4-50**:<br>
# $\phi2 = 27.12+0.2857N$

# %%
dfDealP.insert(5,"phiF", 27.12+0.2857*dfDealP["Nspt"])
# dfDealP.drop("phiF", axis = 1, inplace=True)

# %%
dfDealP[dfDealP["Nspt"] <=10]
# Out:
#           Code  DepthUp  DepthDown  Soil  Density     phiF  Nspt    Phi  \
# 6    S1_TVII-2      7.2        7.8  Clay    2.156  29.9770  10.0  23.64
# 102    S2_TV-2     10.0       10.6  Sand      NaN  29.9770  10.0    NaN
# 116  S9_TVII-2      4.0        4.6  Sand      NaN  28.2628   4.0    NaN
#
#         C3   C2      C1    Cu  Longitude   Latitude            Address
# 6   -0.040  5.0  62.635  0.18  -6.010817  37.390850           C/ Odiel
# 102 -0.040  5.0  62.635   NaN  -5.994999  37.409252  Av. Alvaro Alonso
# 116 -0.124 -7.9  23.731   NaN  -6.005359  37.375627        C/ Santa Fe

# %% [markdown]
# ##### Filling C3 and phiF with Final valuse

# %%
dfDealP.at[116,"phiF"] = 7 * dfDealP.at[116,"Nspt"]
dfDealP.loc[116,]
# Out:
# Code           S9_TVII-2
# DepthUp              4.0
# DepthDown            4.6
# Soil                Sand
# Density              NaN
# phiF                28.0
# Nspt                 4.0
# Phi                  NaN
# C3                -0.124
# C2                  -7.9
# C1                23.731
# Cu                   NaN
# Longitude      -6.005359
# Latitude       37.375627
# Address      C/ Santa Fe
# Name: 116, dtype: object

# %%
dfDealP.at[6,"C3"] = dfDealP.at[6,"C1"]/98.0665
dfDealP.at[102,"C3"] = dfDealP.at[102,"C1"]/98.0665
dfDealP.at[108,"C3"] = dfDealP.at[108,"C1"]/98.0665
dfDealP.at[116,"C3"] = dfDealP.at[116,"C1"]/98.0665

# %%
dfDealP.loc[[6,102,108,116],]
# Out:
#           Code  DepthUp  DepthDown  Soil  Density     phiF  Nspt    Phi  \
# 6    S1_TVII-2      7.2        7.8  Clay    2.156  29.9770  10.0  23.64
# 102    S2_TV-2     10.0       10.6  Sand      NaN  29.9770  10.0    NaN
# 108    S3_TV-2      4.0        4.6  Sand    1.900  30.2627  11.0    NaN
# 116  S9_TVII-2      4.0        4.6  Sand      NaN  28.0000   4.0    NaN
#
#            C3    C2      C1    Cu  Longitude   Latitude               Address
# 6    0.638699  5.00  62.635  0.18  -6.010817  37.390850              C/ Odiel
# 102  0.638699  5.00  62.635   NaN  -5.994999  37.409252     Av. Alvaro Alonso
# 108  0.704818  7.15  69.119   NaN  -5.996847  37.409546  C/ J. Bautista Muñoz
# 116  0.241989 -7.90  23.731   NaN  -6.005359  37.375627           C/ Santa Fe

# %% [markdown]
# #### Based on SPT Number
# If they are in same number so we can use them and fill them.<br>
# So we are going to extract these SPT codes and take a look deeply. <br>
# With realying the C3 number and phiF we can take a look deeply. <br>

# %%
dfDealP[dfDealP["Cu"].isna()].Code.values
# Out:
# array(['S5_TIII-1B', 'S5_TIII-1B', 'S2_TI-1b', 'S4_TI-1b', 'S9_TI-1b',
#        'S4_TVI-1', 'S7_TVII-2', 'SP16', 'SP17', 'S1_TVIII-1', 'S2_TVII-2',
#        'S2_TVII-2', 'S4_TVII-2', 'S4_TVII-2', 'S2_TV-2', 'S3_TV-2',
#        'S9_TVII-2', 'S10_TVII-2'], dtype=object)

# %%
dfDealP[dfDealP["Code"].isin(dfDealP[dfDealP["Cu"].isna()].Code.values) ]
# Out:
#            Code  DepthUp  DepthDown  Soil  Density     phiF  Nspt    Phi  \
# 14   S5_TIII-1B      7.6        8.2  Clay    1.965  36.2624  32.0  25.46
# 15   S5_TIII-1B     13.0       13.6  Sand      NaN  38.8337  41.0    NaN
# 16   S5_TIII-1B     19.0       19.6  Sand      NaN  40.8336  48.0    NaN
# 19     S2_TI-1b      6.0        6.6  Clay      NaN      NaN   NaN  26.64
# 20     S2_TI-1b     12.0       12.6  Clay      NaN  36.2624  32.0    NaN
# 24     S4_TI-1b      4.0        4.6  Clay      NaN      NaN   NaN  15.65
# 27     S4_TI-1b     17.5       18.1  Sand      NaN  36.5481  33.0    NaN
# 31     S9_TI-1b      7.0        7.6  Clay      NaN      NaN   NaN  13.60
# 32     S9_TI-1b     16.0       16.6  Sand      NaN      NaN   NaN  27.22
# 33     S9_TI-1b     19.0       19.6  Sand      NaN  35.1196  28.0    NaN
# 44     S4_TVI-1     10.0       10.6  Sand      NaN  31.6912  16.0    NaN
# 47    S7_TVII-2      7.0        7.6  Clay      NaN      NaN   NaN  13.87
# 48    S7_TVII-2     11.0       11.6  Sand      NaN  32.2626  18.0    NaN
# 53         SP16      5.0        5.6  Clay    1.960  31.6912  16.0  20.39
# 54         SP16     14.0       14.6  Sand      NaN  34.2625  25.0    NaN
# 60         SP17      5.0        5.6  Clay    1.890      NaN   NaN  27.80
# 61         SP17     11.0       11.6  Clay      NaN  31.1198  14.0  20.03
# 62         SP17     14.0       14.6  Sand      NaN  32.8340  20.0    NaN
# 67   S1_TVIII-1     12.1       12.7  Sand      NaN  31.1198  14.0    NaN
# 68   S1_TVIII-1     19.5       20.1  Sand    1.993  34.8339  27.0  17.89
# 73    S2_TVII-2      4.0        4.6  Clay    2.006  32.8340  20.0  23.78
# 74    S2_TVII-2     10.0       10.6  Sand    1.895  33.9768  24.0  27.68
# 75    S2_TVII-2     17.0       17.6  Sand      NaN  34.5482  26.0    NaN
# 76    S2_TVII-2     20.0       20.6  Sand      NaN  49.9760  80.0    NaN
# 87    S4_TVII-2      5.6        6.1  Sand    2.043  35.6910  30.0  31.97
# 88    S4_TVII-2     15.0       15.6  Sand      NaN  36.5481  33.0    NaN
# 89    S4_TVII-2     18.0       18.6  Sand      NaN  35.4053  29.0    NaN
# 101     S2_TV-2      7.0        7.6  Sand    2.060      NaN   NaN  10.81
# 102     S2_TV-2     10.0       10.6  Sand      NaN  29.9770  10.0    NaN
# 108     S3_TV-2      4.0        4.6  Sand    1.900  30.2627  11.0    NaN
# 116   S9_TVII-2      4.0        4.6  Sand      NaN  28.0000   4.0    NaN
# 119  S10_TVII-2      4.0        4.6  Clay    1.900      NaN   NaN   3.50
# 120  S10_TVII-2      7.0        7.6  Sand      NaN  31.6912  16.0    NaN
#
#            C3      C2       C1    Cu  Longitude   Latitude  \
# 14   0.268000   52.30  205.283  0.36  -5.962946  37.401232
# 15   0.394000   71.65  263.639   NaN  -5.962946  37.401232
# 16   0.492000   86.70  309.027   NaN  -5.962946  37.401232
# 19        NaN     NaN      NaN  0.05  -5.986087  37.359260
# 20   0.268000   52.30  205.283   NaN  -5.986087  37.359260
# 24        NaN     NaN      NaN  0.82  -5.977018  37.362171
# 27   0.282000   54.45  211.767   NaN  -5.977018  37.362171
# 31        NaN     NaN      NaN  0.53  -5.983228  37.359866
# 32        NaN     NaN      NaN  0.34  -5.983228  37.359866
# 33   0.212000   43.70  179.347   NaN  -5.983228  37.359866
# 44   0.044000   17.90  101.539   NaN  -6.010093  37.398565
# 47        NaN     NaN      NaN  0.41  -6.010905  37.386979
# 48   0.072000   22.20  114.507   NaN  -6.010905  37.386979
# 53   0.044000   17.90  101.539  0.42  -6.005210  37.375729
# 54   0.170000   37.25  159.895   NaN  -6.005210  37.375729
# 60        NaN     NaN      NaN  0.10  -6.003685  37.370576
# 61   0.016000   13.60   88.571  0.13  -6.003685  37.370576
# 62   0.100000   26.50  127.475   NaN  -6.003685  37.370576
# 67   0.016000   13.60   88.571   NaN  -5.997485  37.369618
# 68   0.198000   41.55  172.863  0.52  -5.997485  37.369618
# 73   0.100000   26.50  127.475  0.33  -6.011196  37.386229
# 74   0.156000   35.10  153.411  0.19  -6.011196  37.386229
# 75   0.184000   39.40  166.379   NaN  -6.011196  37.386229
# 76   0.940000  155.50  516.515   NaN  -6.011196  37.386229
# 87   0.240000   48.00  192.315  0.19  -6.008259  37.379477
# 88   0.282000   54.45  211.767   NaN  -6.008259  37.379477
# 89   0.226000   45.85  185.831   NaN  -6.008259  37.379477
# 101       NaN     NaN      NaN  0.59  -5.994999  37.409252
# 102  0.638699    5.00   62.635   NaN  -5.994999  37.409252
# 108  0.704818    7.15   69.119   NaN  -5.996847  37.409546
# 116  0.241989   -7.90   23.731   NaN  -6.005359  37.375627
# 119       NaN     NaN      NaN  0.63  -6.008791  37.380210
# 120  0.044000   17.90  101.539   NaN  -6.008791  37.380210
#
#                            Address
# 14                 Av. Kansas City
# 15                 Av. Kansas City
# 16                 Av. Kansas City
# 19    Reina Mercedes, Luca de Tena
# 20    Reina Mercedes, Luca de Tena
# 24          Hosp. Virgen del Rocío
# 27          Hosp. Virgen del Rocío
# 31         C/ Marques Luca de Tena
# 32         C/ Marques Luca de Tena
# 33         C/ Marques Luca de Tena
# 44             C/ Americo Vespucio
# 47                    Ronda Triana
# 48                    Ronda Triana
# 53                    Calle Niebla
# 54                    Calle Niebla
# 60            Calle Alfonso Borbon
# 61            Calle Alfonso Borbon
# 62            Calle Alfonso Borbon
# 67   C/ Antonio Bienvenida (Feria)
# 68   C/ Antonio Bienvenida (Feria)
# 73                    Ronda Triana
# 74                    Ronda Triana
# 75                    Ronda Triana
# 76                    Ronda Triana
# 87                 Lopez de Gomara
# 88                 Lopez de Gomara
# 89                 Lopez de Gomara
# 101              Av. Alvaro Alonso
# 102              Av. Alvaro Alonso
# 108           C/ J. Bautista Muñoz
# 116                    C/ Santa Fe
# 119                Lopez de Gomara
# 120                Lopez de Gomara

# %% [markdown]
# **Note:**<br>
# **S5_TIII-1B** has three Nspt valuse, and these valuse validate the C3 and phiF, row 15 and 16 use C3<br>
# **S2_TI-1b** has Cu and Phi for row 19 to row 20 copy.<br>
# **S4_TI-1b** has validated C3 in row 27.<br>
# **S9_TI-1b** has validated C3 in row 33.<br>
# **S4_TVI-1** has validated C3 in row 44.<br>
# **S7_TVII-2** has validated C3 in row 48.<br>
# **SP16** has validated C3 in row 54.<br>
# **SP17** has validated C3 in row 62.<br>
# **S1_TVIII-1** use C2 in row 67.<br>
# **S2_TVII-2** use C3 in row 75 and 76. But row 76 could be outlier because of depth.<br>
# **S4_TVII-2** has validated C3 in row 88 and 89.<br>
# **S2_TV-2** has validated C3 in row 108.<br>
# **S9_TVII-2** has validated C3 in row 116.<br>
# S10_TVII-2 **bold text** has validated C3 in row 120.<br>

# %%
dfDealP.insert(11,"CuNew", dfDealP["Cu"])
# dfDealP.drop("CuNew", axis = 1, inplace=True)

# %%
dfDealP["CuNew"].fillna(dfDealP["C3"], inplace= True)
dfDealP.at[67,"CuNew"] = dfDealP.at[67,"C2"]/98.0665
dfDealP.head()
# Out:
#         Code  DepthUp  DepthDown  Soil  Density     phiF  Nspt    Phi  \
# 1   S1_TI-2C      9.0        9.6  Clay    1.818  32.8340  20.0  23.00
# 2   S1_TI-2C     23.5       24.1  Sand    2.006  35.9767  31.0  30.31
# 3   S1_TI-2C     29.5       30.1  Sand    2.050      NaN   NaN  23.50
# 6  S1_TVII-2      7.2        7.8  Clay    2.156  29.9770  10.0  23.64
# 7  S1_TVII-2      9.7       10.3  Clay    2.063      NaN   NaN  23.14
#
#          C3     C2       C1  CuNew    Cu  Longitude  Latitude  \
# 1  0.100000  26.50  127.475   0.49  0.49  -5.988427  37.36079
# 2  0.254000  50.15  198.799   0.20  0.20  -5.988427  37.36079
# 3       NaN    NaN      NaN   0.47  0.47  -5.988427  37.36079
# 6  0.638699   5.00   62.635   0.18  0.18  -6.010817  37.39085
# 7       NaN    NaN      NaN   0.52  0.52  -6.010817  37.39085
#
#               Address
# 1  Av. Reina Mercedes
# 2  Av. Reina Mercedes
# 3  Av. Reina Mercedes
# 6            C/ Odiel
# 7            C/ Odiel

# %%
dfDealP.insert(4,"PhiNew", dfDealP["Phi"])
# dfDealP.drop("PhiNew", axis = 1, inplace=True)

# %%
dfDealP["PhiNew"].fillna(dfDealP["phiF"], inplace= True)

# %%
dfDealP.head(10)
# Out:
#           Code  DepthUp  DepthDown  Soil   PhiNew  Density     phiF  Nspt  \
# 1     S1_TI-2C      9.0        9.6  Clay  23.0000    1.818  32.8340  20.0
# 2     S1_TI-2C     23.5       24.1  Sand  30.3100    2.006  35.9767  31.0
# 3     S1_TI-2C     29.5       30.1  Sand  23.5000    2.050      NaN   NaN
# 6    S1_TVII-2      7.2        7.8  Clay  23.6400    2.156  29.9770  10.0
# 7    S1_TVII-2      9.7       10.3  Clay  23.1400    2.063      NaN   NaN
# 8    S1_TVII-2     14.0       14.6  Sand  24.4200    1.875  34.8339  27.0
# 14  S5_TIII-1B      7.6        8.2  Clay  25.4600    1.965  36.2624  32.0
# 15  S5_TIII-1B     13.0       13.6  Sand  38.8337      NaN  38.8337  41.0
# 16  S5_TIII-1B     19.0       19.6  Sand  40.8336      NaN  40.8336  48.0
# 19    S2_TI-1b      6.0        6.6  Clay  26.6400      NaN      NaN   NaN
#
#       Phi        C3     C2       C1  CuNew    Cu  Longitude   Latitude  \
# 1   23.00  0.100000  26.50  127.475  0.490  0.49  -5.988427  37.360790
# 2   30.31  0.254000  50.15  198.799  0.200  0.20  -5.988427  37.360790
# 3   23.50       NaN    NaN      NaN  0.470  0.47  -5.988427  37.360790
# 6   23.64  0.638699   5.00   62.635  0.180  0.18  -6.010817  37.390850
# 7   23.14       NaN    NaN      NaN  0.520  0.52  -6.010817  37.390850
# 8   24.42  0.198000  41.55  172.863  0.260  0.26  -6.010817  37.390850
# 14  25.46  0.268000  52.30  205.283  0.360  0.36  -5.962946  37.401232
# 15    NaN  0.394000  71.65  263.639  0.394   NaN  -5.962946  37.401232
# 16    NaN  0.492000  86.70  309.027  0.492   NaN  -5.962946  37.401232
# 19  26.64       NaN    NaN      NaN  0.050  0.05  -5.986087  37.359260
#
#                          Address
# 1             Av. Reina Mercedes
# 2             Av. Reina Mercedes
# 3             Av. Reina Mercedes
# 6                       C/ Odiel
# 7                       C/ Odiel
# 8                       C/ Odiel
# 14               Av. Kansas City
# 15               Av. Kansas City
# 16               Av. Kansas City
# 19  Reina Mercedes, Luca de Tena

# %% [markdown]
# ## PLOT1_Visualization Scatter Plot with Filling Cu and $Φ$

# %%
fig, ax = plt.subplots(3, figsize=(10, 8),dpi= 90)
#ax[0].figure(figsize=(8,7), dpi = 100)
ax[0].scatter(dfDealP["Code"],dfDealP["Nspt"], s = 100)
ax[0].tick_params(axis='x', rotation=60)
ax[0].set_ylabel("Nspt")

ax[1].scatter(dfDealP["Code"],dfDealP["CuNew"], s = 100)
ax[1].tick_params(axis='x', rotation=60)
ax[1].set_ylabel("Cohession")

ax[2].scatter(dfDealP["Code"],dfDealP["PhiNew"], s = 100)
ax[2].tick_params(axis='x', rotation=60)
ax[2].set_ylabel("$\phi$")
# Out:
# Text(0, 0.5, '$\\phi$')

# %% [markdown]
# ## PLOT2_Visualization Scatter Plot with Cohession Vs Nspt_FilledNull

# %%
fig = go.Figure(data=go.Scatter(x=dfDealP['CuNew'],
                                y=dfDealP['Nspt'],
                                mode='markers',
                                marker_color=dfDealP['Nspt'],
                                text=dfDealP['Code'])) # hover text goes here
fig.update_traces(marker=dict(size=12,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.update_layout(title='Cohession Vs Nspt with filled data',xaxis_title="Cohession",
                   yaxis_title="NSPT",
                  font=dict(
                  family="Courier New, monospace",
                  size=18,
                  color="RebeccaPurple"
                  ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="58c4c2bd-ff06-489e-a237-41142810b262" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58c4c2bd-ff06-489e-a237-41142810b262")) {                    Plotly.newPlot(                        "58c4c2bd-ff06-489e-a237-41142810b262",                        [{"marker":{"color":[20.0,31.0,null,10.0,null,27.0,32.0,41.0,48.0,null,32.0,null,33.0,null,null,28.0,null,null,20.0,16.0,null,18.0,16.0,25.0,null,14.0,20.0,14.0,27.0,20.0,24.0,26.0,80.0,null,30.0,33.0,29.0,null,null,10.0,11.0,14.0,4.0,null,16.0,null,16.0],"line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","text":["S1_TI-2C","S1_TI-2C","S1_TI-2C","S1_TVII-2","S1_TVII-2","S1_TVII-2","S5_TIII-1B","S5_TIII-1B","S5_TIII-1B","S2_TI-1b","S2_TI-1b","S4_TI-1b","S4_TI-1b","S9_TI-1b","S9_TI-1b","S9_TI-1b","S6_TIII-1b","S6_TIII-1b","S6_TIII-1b","S4_TVI-1","S7_TVII-2","S7_TVII-2","SP16","SP16","SP17","SP17","SP17","S1_TVIII-1","S1_TVIII-1","S2_TVII-2","S2_TVII-2","S2_TVII-2","S2_TVII-2","S3_TVIII-1","S4_TVII-2","S4_TVII-2","S4_TVII-2","S8_TVII-2","S2_TV-2","S2_TV-2","S3_TV-2","S3_TVII-2","S9_TVII-2","S10_TVII-2","S10_TVII-2","SP14","SP15"],"x":[0.49,0.2,0.47,0.18,0.52,0.26,0.36,0.394,0.492,0.05,0.268,0.82,0.282,0.53,0.34,0.212,0.21,1.12,0.52,0.044,0.41,0.072,0.42,0.17,0.1,0.13,0.1,0.13868140496499823,0.52,0.33,0.19,0.184,0.94,0.6,0.19,0.282,0.226,0.1,0.59,0.6386992499987253,0.7048176492482142,0.16,0.24198885450179217,0.63,0.044,0.18,0.71],"y":[20.0,31.0,null,10.0,null,27.0,32.0,41.0,48.0,null,32.0,null,33.0,null,null,28.0,null,null,20.0,16.0,null,18.0,16.0,25.0,null,14.0,20.0,14.0,27.0,20.0,24.0,26.0,80.0,null,30.0,33.0,29.0,null,null,10.0,11.0,14.0,4.0,null,16.0,null,16.0],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}], ...

# %% [markdown]
# ## PLOT3_Visualization Scatter Plot with Location Vs Nspt_FilledNull

# %%
fig = go.Figure(data=go.Scatter(x=dfDealP['Code'],
                                y=dfDealP['Nspt'],
                                mode='markers',
                                marker_color=dfDealP['CuNew'],
                                text=dfDealP['CuNew'])) # hover text goes here
fig.update_traces(marker=dict(size=12,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.update_layout(title='Location Vs Cohession with filled data',xaxis_title="Location",
                   yaxis_title="Nspt",
                  font=dict(
                  family="Courier New, monospace",
                  size=18,
                  color="RebeccaPurple"
                  ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0983aaca-46f3-4d51-9d0e-16d29e284861" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0983aaca-46f3-4d51-9d0e-16d29e284861")) {                    Plotly.newPlot(                        "0983aaca-46f3-4d51-9d0e-16d29e284861",                        [{"marker":{"color":[0.49,0.2,0.47,0.18,0.52,0.26,0.36,0.394,0.492,0.05,0.268,0.82,0.282,0.53,0.34,0.212,0.21,1.12,0.52,0.044,0.41,0.072,0.42,0.17,0.1,0.13,0.1,0.13868140496499823,0.52,0.33,0.19,0.184,0.94,0.6,0.19,0.282,0.226,0.1,0.59,0.6386992499987253,0.7048176492482142,0.16,0.24198885450179217,0.63,0.044,0.18,0.71],"line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","text":[0.49,0.2,0.47,0.18,0.52,0.26,0.36,0.394,0.492,0.05,0.268,0.82,0.282,0.53,0.34,0.212,0.21,1.12,0.52,0.044,0.41,0.072,0.42,0.17,0.1,0.13,0.1,0.13868140496499823,0.52,0.33,0.19,0.184,0.94,0.6,0.19,0.282,0.226,0.1,0.59,0.6386992499987253,0.7048176492482142,0.16,0.24198885450179217,0.63,0.044,0.18,0.71],"x":["S1_TI-2C","S1_TI-2C","S1_TI-2C","S1_TVII-2","S1_TVII-2","S1_TVII-2","S5_TIII-1B","S5_TIII-1B","S5_TIII-1B","S2_TI-1b","S2_TI-1b","S4_TI-1b","S4_TI-1b","S9_TI-1b","S9_TI-1b","S9_TI-1b","S6_TIII-1b","S6_TIII-1b","S6_TIII-1b","S4_TVI-1","S7_TVII-2","S7_TVII-2","SP16","SP16","SP17","SP17","SP17","S1_TVIII-1","S1_TVIII-1","S2_TVII-2","S2_TVII-2","S2_TVII-2","S2_TVII-2","S3_TVIII-1","S4_TVII-2","S4_TVII-2","S4_TVII-2","S8_TVII-2","S2_TV-2","S2_TV-2","S3_TV-2","S3_TVII-2","S9_TVII-2","S10_TVII-2","S10_TVII-2","SP14","SP15"],"y":[20.0,31.0,null,10.0,null,27.0,32.0,41.0,48.0,null,32.0,null,33.0,null,null,28.0,null,null,20.0,16.0,null,18.0,16.0,25.0,null,14.0,20.0,14.0,27.0,20.0,24.0,26.0,80.0,null,30.0,33.0,29.0,null,null,10.0,11.0,14.0,4.0,null,16.0,null,16.0],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fil ...

# %% [markdown]
# ## Dealing With Outlier

# %% [markdown]
# **Note:**From these reports we can see row 76 is outlier. It is located in high Depth

# %%
dfDealP[dfDealP["Code"] == "S2_TVII-2"]
# Out:
#          Code  DepthUp  DepthDown  Soil   PhiNew  Density     phiF  Nspt  \
# 73  S2_TVII-2      4.0        4.6  Clay  23.7800    2.006  32.8340  20.0
# 74  S2_TVII-2     10.0       10.6  Sand  27.6800    1.895  33.9768  24.0
# 75  S2_TVII-2     17.0       17.6  Sand  34.5482      NaN  34.5482  26.0
# 76  S2_TVII-2     20.0       20.6  Sand  49.9760      NaN  49.9760  80.0
#
#       Phi     C3     C2       C1  CuNew    Cu  Longitude   Latitude  \
# 73  23.78  0.100   26.5  127.475  0.330  0.33  -6.011196  37.386229
# 74  27.68  0.156   35.1  153.411  0.190  0.19  -6.011196  37.386229
# 75    NaN  0.184   39.4  166.379  0.184   NaN  -6.011196  37.386229
# 76    NaN  0.940  155.5  516.515  0.940   NaN  -6.011196  37.386229
#
#          Address
# 73  Ronda Triana
# 74  Ronda Triana
# 75  Ronda Triana
# 76  Ronda Triana

# %% [markdown]
# ## PLOT4_Visualization Scatter Plot with Firction Angle Vs Location_FilledNull

# %%
fig = go.Figure(data=go.Scatter(x=dfDealP['Code'],
                                y=dfDealP['PhiNew'],
                                mode='markers',
                                marker_color=dfDealP['PhiNew'],
                                text=dfDealP['PhiNew'])) # hover text goes here
fig.update_traces(marker=dict(size=12,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.update_layout(title='Location Vs Friction angle iwith filled data',xaxis_title="Location",
                   yaxis_title="Friction angle",
                  font=dict(
                  family="Courier New, monospace",
                  size=18,
                  color="RebeccaPurple"
                  ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7074bcc9-0bb8-4f82-a009-fcedc65ae2c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7074bcc9-0bb8-4f82-a009-fcedc65ae2c5")) {                    Plotly.newPlot(                        "7074bcc9-0bb8-4f82-a009-fcedc65ae2c5",                        [{"marker":{"color":[23.0,30.31,23.5,23.64,23.14,24.42,25.46,38.8337,40.833600000000004,26.64,36.2624,15.65,36.548100000000005,13.6,27.22,35.1196,31.1,16.99,31.93,31.691200000000002,13.87,32.2626,20.39,34.2625,27.8,20.03,32.834,31.1198,17.89,23.78,27.68,34.5482,49.976,22.89,31.97,36.548100000000005,35.4053,32.02,10.81,29.977,30.262700000000002,32.59,28.0,3.5,31.691200000000002,33.53,22.21],"line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","text":[23.0,30.31,23.5,23.64,23.14,24.42,25.46,38.8337,40.833600000000004,26.64,36.2624,15.65,36.548100000000005,13.6,27.22,35.1196,31.1,16.99,31.93,31.691200000000002,13.87,32.2626,20.39,34.2625,27.8,20.03,32.834,31.1198,17.89,23.78,27.68,34.5482,49.976,22.89,31.97,36.548100000000005,35.4053,32.02,10.81,29.977,30.262700000000002,32.59,28.0,3.5,31.691200000000002,33.53,22.21],"x":["S1_TI-2C","S1_TI-2C","S1_TI-2C","S1_TVII-2","S1_TVII-2","S1_TVII-2","S5_TIII-1B","S5_TIII-1B","S5_TIII-1B","S2_TI-1b","S2_TI-1b","S4_TI-1b","S4_TI-1b","S9_TI-1b","S9_TI-1b","S9_TI-1b","S6_TIII-1b","S6_TIII-1b","S6_TIII-1b","S4_TVI-1","S7_TVII-2","S7_TVII-2","SP16","SP16","SP17","SP17","SP17","S1_TVIII-1","S1_TVIII-1","S2_TVII-2","S2_TVII-2","S2_TVII-2","S2_TVII-2","S3_TVIII-1","S4_TVII-2","S4_TVII-2","S4_TVII-2","S8_TVII-2","S2_TV-2","S2_TV-2","S3_TV-2","S3_TVII-2","S9_TVII-2","S10_TVII-2","S10_TVII-2","SP14","SP15"],"y":[23.0,30.31,23.5,23.64,23.14,24.42,25.46,38.8337,40.833600000000004,26.64,36.2624,15.65,36.548100000000005,13.6,27.22,35.1196,31.1,16.99,31.93,31.691200000000002,13.87,32.2626,20.39,34.2625,27.8,20.03,32.834,31.1198,17.89,23.78,27.68,34.5482,49.976,22.89,31.97,36.548100000000005,35.4053,32.02,10.81,29.977,30.262700000000002,32.59,28.0,3.5,31.691200000000002,33.53,22.21],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222 ...

# %% [markdown]
# ## PLOT5_Visualization Scatter Plot with Cohession Vs Location_Based on Cu Color_FilledNull

# %%
fig = go.Figure(data=go.Scatter(x=dfDealP['Code'],
                                y=dfDealP['PhiNew'],
                                mode='markers',
                                marker_color=dfDealP['CuNew'],
                                text=dfDealP['CuNew'])) # hover text goes here
fig.update_traces(marker=dict(size=12,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.update_layout(title='Location Vs Friction angle with filled data and cohession color',xaxis_title="Location",
                   yaxis_title="Friction angle",
                  font=dict(
                  family="Courier New, monospace",
                  size=18,
                  color="RebeccaPurple"
                  ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="61304a38-2271-4554-9d19-11cc7879034e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61304a38-2271-4554-9d19-11cc7879034e")) {                    Plotly.newPlot(                        "61304a38-2271-4554-9d19-11cc7879034e",                        [{"marker":{"color":[0.49,0.2,0.47,0.18,0.52,0.26,0.36,0.394,0.492,0.05,0.268,0.82,0.282,0.53,0.34,0.212,0.21,1.12,0.52,0.044,0.41,0.072,0.42,0.17,0.1,0.13,0.1,0.13868140496499823,0.52,0.33,0.19,0.184,0.94,0.6,0.19,0.282,0.226,0.1,0.59,0.6386992499987253,0.7048176492482142,0.16,0.24198885450179217,0.63,0.044,0.18,0.71],"line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","text":[0.49,0.2,0.47,0.18,0.52,0.26,0.36,0.394,0.492,0.05,0.268,0.82,0.282,0.53,0.34,0.212,0.21,1.12,0.52,0.044,0.41,0.072,0.42,0.17,0.1,0.13,0.1,0.13868140496499823,0.52,0.33,0.19,0.184,0.94,0.6,0.19,0.282,0.226,0.1,0.59,0.6386992499987253,0.7048176492482142,0.16,0.24198885450179217,0.63,0.044,0.18,0.71],"x":["S1_TI-2C","S1_TI-2C","S1_TI-2C","S1_TVII-2","S1_TVII-2","S1_TVII-2","S5_TIII-1B","S5_TIII-1B","S5_TIII-1B","S2_TI-1b","S2_TI-1b","S4_TI-1b","S4_TI-1b","S9_TI-1b","S9_TI-1b","S9_TI-1b","S6_TIII-1b","S6_TIII-1b","S6_TIII-1b","S4_TVI-1","S7_TVII-2","S7_TVII-2","SP16","SP16","SP17","SP17","SP17","S1_TVIII-1","S1_TVIII-1","S2_TVII-2","S2_TVII-2","S2_TVII-2","S2_TVII-2","S3_TVIII-1","S4_TVII-2","S4_TVII-2","S4_TVII-2","S8_TVII-2","S2_TV-2","S2_TV-2","S3_TV-2","S3_TVII-2","S9_TVII-2","S10_TVII-2","S10_TVII-2","SP14","SP15"],"y":[23.0,30.31,23.5,23.64,23.14,24.42,25.46,38.8337,40.833600000000004,26.64,36.2624,15.65,36.548100000000005,13.6,27.22,35.1196,31.1,16.99,31.93,31.691200000000002,13.87,32.2626,20.39,34.2625,27.8,20.03,32.834,31.1198,17.89,23.78,27.68,34.5482,49.976,22.89,31.97,36.548100000000005,35.4053,32.02,10.81,29.977,30.262700000000002,32.59,28.0,3.5,31.691200000000002,33.53,22.21],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0 ...

# %% [markdown]
# ## PLOT6_Visualization Scatter Plot with Cohession Vs Nspt_Based on Location_FilledNull

# %%
fig = go.Figure(data=go.Scatter(x=dfDealP['CuNew'],
                                y=dfDealP['Nspt'],
                                mode='markers',
                                marker_color=dfDealP['Longitude'],
                                text=dfDealP['Code'])) # hover text goes here
fig.update_traces(marker=dict(size=12,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.update_layout(title='Cohession Vs Nspt with filled data compared with Longitude',xaxis_title="Cohession",
                   yaxis_title="NSPT",
                  font=dict(
                  family="Courier New, monospace",
                  size=18,
                  color="RebeccaPurple"
                  ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1b683495-5555-4011-880f-62fa9e7ead98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b683495-5555-4011-880f-62fa9e7ead98")) {                    Plotly.newPlot(                        "1b683495-5555-4011-880f-62fa9e7ead98",                        [{"marker":{"color":[-5.98842652,-5.98842652,-5.98842652,-6.01081699,-6.01081699,-6.01081699,-5.962946076,-5.962946076,-5.962946076,-5.986086732,-5.986086732,-5.977017532,-5.977017532,-5.98322777,-5.98322777,-5.98322777,-5.963095764,-5.963095764,-5.963095764,-6.010092725,-6.010904693,-6.010904693,-6.005209529,-6.005209529,-6.003684918,-6.003684918,-6.003684918,-5.997485404,-5.997485404,-6.011196311,-6.011196311,-6.011196311,-6.011196311,-5.994371801,-6.008259307,-6.008259307,-6.008259307,-6.009896212,-5.994998717,-5.994998717,-5.996847285,-6.010847908,-6.005359108,-6.00879107,-6.00879107,-6.009466093,-6.010118577],"line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","text":["S1_TI-2C","S1_TI-2C","S1_TI-2C","S1_TVII-2","S1_TVII-2","S1_TVII-2","S5_TIII-1B","S5_TIII-1B","S5_TIII-1B","S2_TI-1b","S2_TI-1b","S4_TI-1b","S4_TI-1b","S9_TI-1b","S9_TI-1b","S9_TI-1b","S6_TIII-1b","S6_TIII-1b","S6_TIII-1b","S4_TVI-1","S7_TVII-2","S7_TVII-2","SP16","SP16","SP17","SP17","SP17","S1_TVIII-1","S1_TVIII-1","S2_TVII-2","S2_TVII-2","S2_TVII-2","S2_TVII-2","S3_TVIII-1","S4_TVII-2","S4_TVII-2","S4_TVII-2","S8_TVII-2","S2_TV-2","S2_TV-2","S3_TV-2","S3_TVII-2","S9_TVII-2","S10_TVII-2","S10_TVII-2","SP14","SP15"],"x":[0.49,0.2,0.47,0.18,0.52,0.26,0.36,0.394,0.492,0.05,0.268,0.82,0.282,0.53,0.34,0.212,0.21,1.12,0.52,0.044,0.41,0.072,0.42,0.17,0.1,0.13,0.1,0.13868140496499823,0.52,0.33,0.19,0.184,0.94,0.6,0.19,0.282,0.226,0.1,0.59,0.6386992499987253,0.7048176492482142,0.16,0.24198885450179217,0.63,0.044,0.18,0.71],"y":[20.0,31.0,null,10.0,null,27.0,32.0,41.0,48.0,null,32.0,null,33.0,null,null,28.0,null,null,20.0,16.0,null,18.0,16.0,25.0,null,14.0,20.0,14.0,27.0,20.0,24.0,26.0,80.0,null,30.0,33.0,29.0,null,null,10.0,11.0,14.0,4.0,null,16.0,null,16.0],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46 ...

# %% [markdown]
# ## PLOT7_Visualization Scatter Plot with Cohession Vs Nspt_Based on Location2_FilledNull

# %%
fig = go.Figure(data=go.Scatter(x=dfDealP['CuNew'],
                                y=dfDealP['Nspt'],
                                mode='markers',
                                marker_color=dfDealP['Latitude'],
                                text=dfDealP['Code'])) # hover text goes here
fig.update_traces(marker=dict(size=12,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.update_layout(title='Cohession Vs Nspt with filled data compared with Latitude',xaxis_title="Cohession",
                   yaxis_title="NSPT",
                  font=dict(
                  family="Courier New, monospace",
                  size=18,
                  color="RebeccaPurple"
                  ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="17cc95be-1ada-4708-9926-c023a7eca2b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("17cc95be-1ada-4708-9926-c023a7eca2b6")) {                    Plotly.newPlot(                        "17cc95be-1ada-4708-9926-c023a7eca2b6",                        [{"marker":{"color":[37.36078976,37.36078976,37.36078976,37.39084963,37.39084963,37.39084963,37.40123185,37.40123185,37.40123185,37.35925969,37.35925969,37.36217088,37.36217088,37.35986605,37.35986605,37.35986605,37.40174222,37.40174222,37.40174222,37.39856536,37.38697891,37.38697891,37.37572944,37.37572944,37.37057562,37.37057562,37.37057562,37.36961775,37.36961775,37.38622922,37.38622922,37.38622922,37.38622922,37.36477435,37.37947661,37.37947661,37.37947661,37.38186209,37.40925223,37.40925223,37.40954634,37.38349083,37.37562743,37.38020963,37.38020963,37.40014268,37.39423389],"line":{"color":"DarkSlateGrey","width":2},"size":12},"mode":"markers","text":["S1_TI-2C","S1_TI-2C","S1_TI-2C","S1_TVII-2","S1_TVII-2","S1_TVII-2","S5_TIII-1B","S5_TIII-1B","S5_TIII-1B","S2_TI-1b","S2_TI-1b","S4_TI-1b","S4_TI-1b","S9_TI-1b","S9_TI-1b","S9_TI-1b","S6_TIII-1b","S6_TIII-1b","S6_TIII-1b","S4_TVI-1","S7_TVII-2","S7_TVII-2","SP16","SP16","SP17","SP17","SP17","S1_TVIII-1","S1_TVIII-1","S2_TVII-2","S2_TVII-2","S2_TVII-2","S2_TVII-2","S3_TVIII-1","S4_TVII-2","S4_TVII-2","S4_TVII-2","S8_TVII-2","S2_TV-2","S2_TV-2","S3_TV-2","S3_TVII-2","S9_TVII-2","S10_TVII-2","S10_TVII-2","SP14","SP15"],"x":[0.49,0.2,0.47,0.18,0.52,0.26,0.36,0.394,0.492,0.05,0.268,0.82,0.282,0.53,0.34,0.212,0.21,1.12,0.52,0.044,0.41,0.072,0.42,0.17,0.1,0.13,0.1,0.13868140496499823,0.52,0.33,0.19,0.184,0.94,0.6,0.19,0.282,0.226,0.1,0.59,0.6386992499987253,0.7048176492482142,0.16,0.24198885450179217,0.63,0.044,0.18,0.71],"y":[20.0,31.0,null,10.0,null,27.0,32.0,41.0,48.0,null,32.0,null,33.0,null,null,28.0,null,null,20.0,16.0,null,18.0,16.0,25.0,null,14.0,20.0,14.0,27.0,20.0,24.0,26.0,80.0,null,30.0,33.0,29.0,null,null,10.0,11.0,14.0,4.0,null,16.0,null,16.0],"type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8" ...

# %% [markdown]
# # Distribution of data

# %% [markdown]
# ### Descriptive statistics_55 Data

# %%
df1.iloc[:,[4,-4,-5,-6]].describe().applymap('{:,.2f}'.format)
# Out:
#       Density   Nspt    Phi     Cu
# count   29.00  32.00  29.00  29.00
# mean     1.94  24.53  23.36   0.39
# std      0.23  13.97   7.27   0.25
# min      0.85   4.00   3.50   0.05
# 25%      1.90  16.00  20.03   0.19
# 50%      1.97  22.00  23.64   0.36
# 75%      2.02  30.25  27.80   0.52
# max      2.16  80.00  33.53   1.12

# %% [markdown]
# ### Descriptive statistics_Filled

# %%
dfDealP.columns
# Out:
# Index(['Code', 'DepthUp', 'DepthDown', 'Soil', 'PhiNew', 'Density', 'phiF',
#        'Nspt', 'Phi', 'C3', 'C2', 'C1', 'CuNew', 'Cu', 'Longitude', 'Latitude',
#        'Address'],
#       dtype='object')

# %%
dfDealP.iloc[:,[5,7,4,-5]].describe().applymap('{:,.2f}'.format)
# Out:
#       Density   Nspt PhiNew  CuNew
# count   23.00  32.00  47.00  47.00
# mean     1.98  24.53  27.74   0.36
# std      0.08  13.97   8.54   0.25
# min      1.82   4.00   3.50   0.04
# 25%      1.91  16.00  23.07   0.18
# 50%      1.98  22.00  29.98   0.28
# 75%      2.03  30.25  32.71   0.52
# max      2.16  80.00  49.98   1.12

# %% [markdown]
# ## Box plot for disturbation

# %% [markdown]
# ### Box plot for Friction Angle

# %% [markdown]
# #### For Filled Data

# %%
boxPlotDen = dfDealP.boxplot(column=['PhiNew'], grid=False, rot=45, fontsize=10)

# %% [markdown]
# #### For 55 data

# %%
boxPlotDen = df1.boxplot(column=['Phi'], grid=False, rot=45, fontsize=10)

# %% [markdown]
# ### Box plot for Cohession

# %% [markdown]
# #### For 55 Data

# %%
boxPlotDen = df1.boxplot(column=['Cu'], grid=False, rot=45, fontsize=10)

# %% [markdown]
# #### For Filled Data

# %%
boxPlotDen = dfDealP.boxplot(column=['CuNew'], grid=False, rot=45, fontsize=10)

# %% [markdown]
# ## Scatter Plot

# %%
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sb.set_theme(style="ticks", rc=custom_params)
sb.pairplot(dfDealP.iloc[:,[3,4,5,6,-5]], hue="Soil")

# %% [markdown]
# # save

# %%
pathSave = '/content/gdrive/MyDrive/Colab Notebooks/dataAnalySPT/datasetNAFill.csv'

with open(pathSave, 'w', encoding = 'utf-8-sig') as f:
  dfDealP.to_csv(f)
